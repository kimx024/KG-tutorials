# %% [markdown]
# # Knowledge Representation on the Web -- RDFS tutorial
#
# Here we'll learn the basics of RDFS (RDF Schema) and how to perform basic RDFS reasoning with rdflib (documentation [here](https://rdflib.readthedocs.io/en/stable/)) and owlrl (documentation [here](https://owl-rl.readthedocs.io/en/latest/)).

# %% [markdown]
# ## Imports
#
# owlrl is a library implementing basic RDFS and OWL reasoning on top of rdflib. We'll install and import its relevant symbols.

# %%
import sys

from rdflib import Graph, RDFS, RDF, URIRef, Namespace, Literal
from owlrl import DeductiveClosure, RDFS_Semantics

# %% [markdown]
# ## Loading RDFS graphs
#
# Your file `yourRDF.ttl` already contains a basic Knowledge Graph in RDF with some RDFS semantics
#
# First, we are going to add some RDFS semantics, and inspect the graph as-is; this is also called the "asserted graph"
#
# **Exercise 1**
# 1. add additional triples using the RDFS semantics: have a look [here](https://www.w3.org/TR/rdf-schema/), and use domain and range, subPropertyOf, propertyOf, and Class, to say more about the instances in your graph
# 2. load yourRDF graph
# 3. print the classes in your graph
# 4. print the properties of a specific class in yourRDF graph
# 5. print all instances in yourRDF graph (all objects that have a type)
# 6. explain what constitutes a vocabulary in RDF

# %%
g = Graph()

#example namespace
EX = Namespace("https://example.org/")

# Add triples using store's add method.
g.add( (EX.whale, RDF.type, EX.Mammalia) )
g.add( (EX.whale, RDFS.label, Literal('whale'))) #in this example, the identifiers have human readable names, but these can also be arbitrary strings. rdfs:label makes these human-interpretable.  
g.add( (EX.crocodile, RDF.type, EX.Amphibia) )
g.add( (EX.Amphibia, RDFS.subClassOf, EX.Animalia) )
g.add( (EX.whale, EX.eats, EX.crocodile) )

g.serialize(destination="../data/yourRDF.ttl")


print("All classes:")
for objects in g.objects(None, RDF.type):
    print(objects)
    
mammaliaProperty = list()
for s,p,o in g.triples((None, RDF.type, EX.Mammalia)):

    # now we check which predicates a mammalia class has 
    for s1,p1,o1 in g.triples((s,None,None)):
        mammaliaProperty.append(p1)

print("All properties of the Mammalia class:", mammaliaProperty)

print("All instances:")
for subjects in g.subjects(RDF.type, None):
    print(subjects)
# Out:
# All classes:
# https://example.org/Mammalia
# https://example.org/Amphibia
# All properties of the Mammalia class: [rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('https://example.org/eats')]
# All instances:
# https://example.org/whale
# https://example.org/crocodile

# %% [markdown]
# 6. explain what constitutes a vocabulary in RDF:
# ["On the Semantic Web, vocabularies define the concepts and relationships (also referred to as “terms”) used to describe and represent an area of concern."](https://www.w3.org/standards/semanticweb/ontology)
# In our case, the example vocabulary describes classes and subclasses in the natural domain, and how they relate to one another (ex:eats))

# %% [markdown]
# ## RDFS inferencing
#
# The inference engine in owlrl is triggered by `DeductiveClosure`, which computes the closure of the graph. This requires us to specify under which semantic regime we want to perform the inference (e.g. what kind of rules under the RDFS, OWL, etc. semantics we want the reasoner to produce derivations on). For RDFS semantics we use `RDFS_Semantics` as parameter. See extra options [here](https://owl-rl.readthedocs.io/en/latest/stubs/owlrl.html#module-owlrl)
#
#
# **Exercise 2**
# 1. expand the graph through RDFS semantics inference
# 2. print how many triples the new graph has
# 3. print out the triples in your new graph and inspect them.

# %%
e = Graph()
e.parse("../data/yourRDF.ttl")

DeductiveClosure(RDFS_Semantics).expand(e)
print("RDFS closure of the graph has {} triples, the initial graph had {}".format(len(e), len(g)))

for s,p,o in sorted(e.triples((None,None,None))):
    if o != RDFS.Resource:
        print(s,p,o)
# Out:
# RDFS closure of the graph has 22 triples, the initial graph had 5
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# https://example.org/Amphibia http://www.w3.org/2000/01/rdf-schema#subClassOf https://example.org/Animalia
# https://example.org/crocodile http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://example.org/Amphibia
# https://example.org/crocodile http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://example.org/Animalia
# https://example.org/eats http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# https://example.org/eats http://www.w3.org/2000/01/rdf-schema#subPropertyOf https://example.org/eats
# https://example.org/whale http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://example.org/Mammalia
# https://example.org/whale http://www.w3.org/2000/01/rdf-schema#label whale
# https://example.org/whale https://example.org/eats https://example.org/crocodile

# %% [markdown]
# ## The explicit (asserted) graph vs the implicit (derived) graph, and RDF entailment
#
# Asserted triples are those that are explicitly stated, while derived or inferred triples are those that are implicitly stated through the semantics of RDFS.
#
# **Exercise 3**
#
# 1. Write here code to generate a graph that contains **RDFS derived triples only** from yourRDF Knowledge Graph, not the asserted ones. See a clue on rdflib graph algebra [here](https://rdflib.readthedocs.io/en/stable/merging.html)
# 2. have a look at the inferred graph. Based on the RDFS semantics, explain for each triple the rule that was used to generate it.
# 3. Explain the concept RDF entailment, and the types of entailment RDFS can produce

# %%
d = Graph()

d = e - g

print("RDFS inference generated additional {} triples".format(len(d)))

for s,p,o in sorted(d.triples((None,None,None))):
    print(s,p,o)
# Out:
# RDFS inference generated additional 17 triples
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# https://example.org/Amphibia http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://example.org/Animalia http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://example.org/Mammalia http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://example.org/crocodile http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://example.org/crocodile http://www.w3.org/1999/02/22-rdf-syntax-ns#type https://example.org/Animalia
# https://example.org/eats http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# https://example.org/eats http://www.w3.org/2000/01/rdf-schema#subPropertyOf https://example.org/eats
# https://example.org/whale http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# whale http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource

# %% [markdown]
# ## Assignment part 2: your own webapplication.

# %% [markdown]
# **Exercise 4**
# 1. load ingredients.rdf and recipes.rdf in one graph. The graph contains types of individuals and types of relationships between them. Print all the classes and properties in the combined graph with the namespace `ind` and the `wtm` namespace/vocabulary (`http://purl.org/heals/food/`).
#
# 2. extend the `ind` vocabulary (`http://purl.org/heals/ingredient/`) by creating a hierarchy of ingredients (**hint: http://purl.org/heals/ingredient/CoconutMilk rdf:subClassOf http://purl.org/heals/ingredient/PlantMilk), and make these superclasses human readable by giving them labels**)
# 3. do the same for the `wtm` vocabulary: add a hierarchy of recipes as well as a hierarchy of properties (**hint: http://purl.org/heals/food/hasCookingTemperature rdf:subPropertyOf ...)
# 4. print the entailed triples as we did in the previous exercise
# 5. give three examples of how RDF semantics could aid the chefs in your restaurant
#
# 6. which properties and classes could you add to the `wtm` and `ind` vocabularies to further describe your recipe and ingredient knowledge graph, aiding the chefs in your restaurant?

# %%
g = Graph()
g.parse("data/ingredients.rdf")
g.parse("data/recipes.rdf")


ind = Namespace("http://purl.org/heals/ingredient/")
wtm = Namespace("http://purl.org/heals/food/")

classes = list()
for ob in g.objects(None, RDF.type):
  if ob in wtm or ob in ind: 
    classes.append(ob)
    #print("these are the classes") 
    #print(ob)
    Property = list()
    for s,p,o in g.triples((None, RDF.type, None)):
      for s1,p1,o1 in g.triples((s,None,None)):
        Property.append(p1)
        #print("these are the properties")
        #print(p1)

print("these are the classes")        
print(list(classes) )
print("")
print("these are the properties")
print(list(Property))
# Out:
# these are the classes
# [rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.org/heals/food/Ingredient'), rdflib.term.URIRef('http://purl.or ...
#
# these are the properties
# [rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#versionIRI'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#imports'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#imports'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#priorVersion'), rdflib.term.URIRef('http://purl.org/dc/terms/contributor'), rdflib.term.URIRef('http://purl.org/dc/terms/contributor'), rdflib.term.URIRef('http://purl.org/dc/terms/contributor'), rdflib.term.URIRef('http://purl.org/dc/terms/contributor'), rdflib.term.URIRef('http://purl.org/dc/terms/modified'), rdflib.term.URIRef('http://purl.org/dc/terms/description'), rdflib.term.URIRef('http://purl.org/dc/terms/abstract'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#changeNote'), rdflib.term.URIRef('http://purl.org/dc/terms/publisher'), rdflib.term.URIRef('https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright'), rdflib.term.URIRef('http://purl.org/dc/terms/license'), rdflib.term.URIRef('http://purl.org/dc/terms/references'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/heals/food/hasGluten'), rdflib.term.URIRef('http://purl.org/heals/food/hasGlycemicIndex'), rdflib.term.URIRef('http://purl.org/dc/terms/source'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#scopeNote'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/heals/food/hasTexture'), rdflib.term.URIRef('http://purl.org/heals/food/substitutesFor'), rdflib.term.URIRef('http://purl.org/heals/food/substitutesFor'), rdflib.term.URIRef('http://purl.org/heals/food/substitutesFor'), rdflib.term.URIRef('http://purl.org/heals/food/hasGluten'), rdflib.term.URIRef('http://purl.org/heals/food/hasGlycemicIndex'), rdflib.term.URIRef('http://purl.org/dc/terms/source'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#scopeNote'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/heals/food/hasGluten'), rdflib.term.URIRef('http://purl.org/heals/food/hasGlycemicIndex'), rdflib.term.URIRef('http://purl.org/dc/terms/source'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#scopeNote'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://purl.org/heals/food/hasGluten'), rdflib.term.URIRef('http://purl.org/heals/food/hasGlycemicIndex'), rdflib.term.URIRef('http://purl.org/dc/terms/source'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition'), rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#scopeNote'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#ty ...

# %%
#Extend ind vocabulary
g.add( (ind.PlantMilk, RDFS.subClassOf, ind.ingredient) )
g.add( (ind.CoconutMilk, RDFS.subClassOf, ind.PlantMilk) )


g.add( (ind.Fruit, RDFS.subClassOf, ind.ingredient) )
g.add ((ind.Banana, RDFS.subClassOf, ind.Fruit ))
g.add ((ind.Blueberry, RDFS.subClassOf, ind.Fruit ))

g.add( (ind.Vegetables, RDFS.subClassOf, ind.ingredient) )
g.add ((ind.Potato, RDFS.subClassOf, ind.Vegetables ))
g.add ((ind.Celery, RDFS.subClassOf, ind.Vegetables ))
g.add ((ind.Cabbage, RDFS.subClassOf, ind.Vegetables ))
g.add ((ind.Tomato, RDFS.subClassOf, ind.Vegetables ))

g.add( (ind.Spice, RDFS.subClassOf, ind.ingredient) )
g.add ((ind.Thyme, RDFS.subClassOf, ind.Spice ))
g.add ((ind.Basil, RDFS.subClassOf, ind.Spice ))
g.add ((ind.BlackPepper, RDFS.subClassOf, ind.Spice ))

g.add( (ind.Fruit, RDFS.label, Literal('Fruit')))
g.add( (ind.Vegetables, RDFS.label, Literal('Vegetables')))
g.add( (ind.Spice, RDFS.label, Literal('Spice')))
g.add( (ind.PlantMilk, RDFS.label, Literal('PlantMilk')))
# Out:
# <Graph identifier=Nf85d51aa93f3491ca431381fdfff4fb3 (<class 'rdflib.graph.Graph'>)>

# %%
#extednd wtm vocabulary
g.add((wtm.Meal, RDF.type, RDFS.Class))
g.add((wtm.Lunch, RDFS.subClassOf, wtm.Meal))
g.add((wtm.Breakfast, RDFS.subClassOf, wtm.Meal))
g.add((wtm.Dinner, RDFS.subClassOf, wtm.Meal))


g.add( (wtm.hasGluten, RDFS.subPropertyOf, wtm.hasIngredient) )

g.add(( wtm.procedure, RDF.type, RDF.Property))
g.add(( wtm.hasCookTime, RDFS.subPropertyOf,wtm.procedure ))
g.add(( wtm.hasCookingTemperature, RDFS.subPropertyOf,wtm.procedure ))
# Out:
# <Graph identifier=Nf85d51aa93f3491ca431381fdfff4fb3 (<class 'rdflib.graph.Graph'>)>

# %%
#print entailed triples
e = Graph()
e.parse("data/ingredients.rdf")
e.parse("data/recipes.rdf")
DeductiveClosure(RDFS_Semantics).expand(e)

d = Graph()

d = e - g

print("RDFS inference generated additional {} triples".format(len(d)))

for s,p,o in sorted(d.triples((None,None,None))):
    print(s,p,o)
# Out:
# RDFS inference generated additional 844 triples
# http://purl.obolibrary.org/obo/FOODON_03400662 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400663 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400666 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400667 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400670 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400671 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400673 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400674 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400675 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400676 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400677 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400678 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400681 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400682 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400683 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400685 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400686 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400688 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400689 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400744 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400756 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400759 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400760 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400764 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400766 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400774 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400775 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.obolibrary.org/obo/FOODON_03400776 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/dc/terms/abstract http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/abstract http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/abstract
# http://purl.org/dc/terms/contributor http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/contributor http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/contributor
# http://purl.org/dc/terms/description http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/description http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/description
# http://purl.org/dc/terms/license http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/license http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/license
# http://purl.org/dc/terms/modified http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/modified http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/modified
# http://purl.org/dc/terms/publisher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/publisher http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/publisher
# http://purl.org/dc/terms/references http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/references http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/references
# http://purl.org/dc/terms/source http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/dc/terms/source http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/dc/terms/source
# http://purl.org/heals/food/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Appetizer http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Breakfast http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/ChemicalFoodProduct http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Dessert http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Dinner http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Entree http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Flavor http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Ingredient http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Lunch http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/MeatFromChicken http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/MeatFromCow http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/MeatFromLamb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/MilkFromCow http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Recipe http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Side http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Snack http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/TemperatureMeasurement http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Texture http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/TimeMeasurement http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/User http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/Yeast http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/food/dislikes http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/dislikes http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/dislikes
# http://purl.org/heals/food/forbids http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/forbids http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/forbids
# http://purl.org/heals/food/hasCookTime http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/hasCookTime http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/hasCookTime
# http://purl.org/heals/food/hasCookingTemperature http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/hasCookingTemperature http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/hasCookingTemperature
# http://purl.org/heals/food/hasGluten http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/hasGluten http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/hasGlycemicIndex http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/heals/food/hasIngredient http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/hasIngredient http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/hasIngredient
# http://purl.org/heals/food/hasTexture http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/hasTexture http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/hasTexture
# http://purl.org/heals/food/isAllergicTo http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/isAllergicTo http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/isAllergicTo
# http://purl.org/heals/food/isRecommendedForCourse http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/isRecommendedForCourse http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/isRecommendedForCourse
# http://purl.org/heals/food/isRecommendedForMeal http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/isRecommendedForMeal http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/isRecommendedForMeal
# http://purl.org/heals/food/serves http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/serves http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/serves
# http://purl.org/heals/food/substitutesFor http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://purl.org/heals/food/substitutesFor http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://purl.org/heals/food/substitutesFor
# http://purl.org/heals/ingredient/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/AllPurposeFlour http://purl.org/heals/food/hasGluten 1
# http://purl.org/heals/ingredient/AllPurposeFlour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Almond http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Almond http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Almond http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/AlmondBiscotti http://purl.org/heals/food/serves 15
# http://purl.org/heals/ingredient/AlmondBiscotti http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/AlmondMeal http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/AlmondMeal http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/AppleCiderVinegar http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/AppleCiderVinegar http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/AppleCiderVinegar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Bacon http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Bacon http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Bacon http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BakedChickenTender http://purl.org/heals/food/hasCookTime 45
# http://purl.org/heals/ingredient/BakedChickenTender http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BakersYeast http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BakersYeast http://purl.org/heals/food/hasGlycemicIndex 35
# http://purl.org/heals/ingredient/BakersYeast http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BakingPowder http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BakingPowder http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/BakingPowder http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BakingSoda http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BakingSoda http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/BakingSoda http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BalsamicVinegar http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BalsamicVinegar http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/BalsamicVinegar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Banana http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Banana http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BananaBlueberryAlmondFlourMuffin http://purl.org/heals/food/hasCookTime 60
# http://purl.org/heals/ingredient/BananaBlueberryAlmondFlourMuffin http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BananaBread http://purl.org/heals/food/serves 10
# http://purl.org/heals/ingredient/BananaBread http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Basil http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Basil http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/Basil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Beef http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Beef http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Beef http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BeefBouillon http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BeefBouillon http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/BeefBouillon http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BeefNilaga http://purl.org/heals/food/serves 5
# http://purl.org/heals/ingredient/BeefNilaga http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BeefStew http://purl.org/heals/food/serves 10
# http://purl.org/heals/ingredient/BeefStew http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Bitter http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BlackPepper http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BlackPepper http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/BlackPepper http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BlackPeppercorn http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BlackPeppercorn http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/BlackPeppercorn http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Blueberry http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Blueberry http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BraisedBalsamicChicken http://purl.org/heals/food/hasCookTime 35
# http://purl.org/heals/ingredient/BraisedBalsamicChicken http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/BrownSugar http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/BrownSugar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Brownies http://purl.org/heals/food/hasCookTime 60
# http://purl.org/heals/ingredient/Brownies http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Butter http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Butter http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Butter http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Cabbage http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Cabbage http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Cabbage http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CaneSugar http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/CaneSugar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CanolaOil http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/CanolaOil http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/CanolaOil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Carrot http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Carrot http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Carrot http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Celery http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Celery http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Celery http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Celsius http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/ChayoteSquash http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/ChayoteSquash http://purl.org/heals/food/hasGlycemicIndex 50
# http://purl.org/heals/ingredient/ChayoteSquash http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Cheese http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Cheese http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Cheese http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Chicken http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Chicken http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Chicken http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/ChickenBroth http://purl.org/heals/food/hasGluten 1
# http://purl.org/heals/ingredient/ChickenBroth http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/ChickenBroth http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/ChickenEgg http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/ChickenEgg http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/ChickenEgg http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/ChickenSalad http://purl.org/heals/food/hasCookTime 15
# http://purl.org/heals/ingredient/ChickenSalad http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/ChuckRoast http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/ChuckRoast http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/ChuckRoast http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Cilantro http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Cilantro http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Cilantro http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Clove http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Clove http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/Clove http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CocoaPowder http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/CocoaPowder http://purl.org/heals/food/hasGlycemicIndex 20
# http://purl.org/heals/ingredient/CocoaPowder http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Coconut http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Coconut http://purl.org/heals/food/hasGlycemicIndex 35
# http://purl.org/heals/ingredient/Coconut http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CoconutMilk http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/CoconutMilk http://purl.org/heals/food/hasGlycemicIndex 40
# http://purl.org/heals/ingredient/CoconutMilk http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CornSyrup http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/CornSyrup http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CornedBeef http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/CornedBeef http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/CornedBeef http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CornedBeefHash http://purl.org/heals/food/hasCookTime 40
# http://purl.org/heals/ingredient/CornedBeefHash http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Cornstarch http://purl.org/heals/food/hasGlycemicIndex 0
# http://purl.org/heals/ingredient/Cornstarch http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/CowMilk http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/CowMilk http://purl.org/heals/food/hasGlycemicIndex 30
# http://purl.org/heals/ingredient/CowMilk http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Creamy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Crumbly http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Crunchy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/DriedCranberry http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/DriedCranberry http://purl.org/heals/food/hasGlycemicIndex 30
# http://purl.org/heals/ingredient/DriedCranberry http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Fahrenheit http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/FlourlessCoconutAndAlmondCake http://purl.org/heals/food/hasCookTime 60
# http://purl.org/heals/ingredient/FlourlessCoconutAndAlmondCake http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Garlic http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Garlic http://purl.org/heals/food/hasGlycemicIndex 30
# http://purl.org/heals/ingredient/Garlic http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/GlutenFreeCoconutCake http://purl.org/heals/food/hasCookTime 60
# http://purl.org/heals/ingredient/GlutenFreeCoconutCake http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/GlutenFreeFlour http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/GlutenFreeFlour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/GoldenKamutBread http://purl.org/heals/food/serves true
# http://purl.org/heals/ingredient/GoldenKamutBread http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Gooey http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Greasy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/GreenOnion http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/GreenOnion http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/GreenOnion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/GreenPepper http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/GreenPepper http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/GreenPepper http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/GrilledChickenKabob http://purl.org/heals/food/hasCookTime 60
# http://purl.org/heals/ingredient/GrilledChickenKabob http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Honey http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Honey http://purl.org/heals/food/hasGlycemicIndex 60
# http://purl.org/heals/ingredient/Honey http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Hour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Kamut http://purl.org/heals/food/hasGluten 1
# http://purl.org/heals/ingredient/Kamut http://purl.org/heals/food/hasGlycemicIndex 45
# http://purl.org/heals/ingredient/Kamut http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/KamutFlour http://purl.org/heals/food/hasGluten 1
# http://purl.org/heals/ingredient/KamutFlour http://purl.org/heals/food/hasGlycemicIndex 45
# http://purl.org/heals/ingredient/KamutFlour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/KamutMuffin http://purl.org/heals/food/hasCookTime 30
# http://purl.org/heals/ingredient/KamutMuffin http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/KamutPancake http://purl.org/heals/food/hasCookTime 45
# http://purl.org/heals/ingredient/KamutPancake http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Lamb http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Lamb http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Lamb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/LemonJuice http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/LemonJuice http://purl.org/heals/food/hasGlycemicIndex 20
# http://purl.org/heals/ingredient/LemonJuice http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Mayonnaise http://purl.org/heals/food/hasGluten 1
# http://purl.org/heals/ingredient/Mayonnaise http://purl.org/heals/food/hasGlycemicIndex 60
# http://purl.org/heals/ingredient/Mayonnaise http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Minute http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Moist http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Mushy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Nutty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Oat http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Oat http://purl.org/heals/food/hasGlycemicIndex 40
# http://purl.org/heals/ingredient/Oat http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/OliveOil http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/OliveOil http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/OliveOil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Onion http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Onion http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Onion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Oregano http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Oregano http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/Oregano http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Paprika http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Paprika http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Paprika http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Parsley http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Parsley http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/Parsley http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Peanut http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Peanut http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Peanut http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Pecan http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Pecan http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Pecan http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/PotRoastWithVegetables http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Potato http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Potato http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/PumpkinSeed http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/PumpkinSeed http://purl.org/heals/food/hasGlycemicIndex 10
# http://purl.org/heals/ingredient/PumpkinSeed http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Rosemary http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Rosemary http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/Rosemary http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Salt http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Salt http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Salt http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Salty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/SaucyShepherdPie http://purl.org/heals/food/hasCookTime 50
# http://purl.org/heals/ingredient/SaucyShepherdPie http://purl.org/heals/food/serves 5
# http://purl.org/heals/ingredient/SaucyShepherdPie http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/SesameOil http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/SesameOil http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/SesameOil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Smoky http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/SmotheredChickenBreast http://purl.org/heals/food/hasCookTime 35
# http://purl.org/heals/ingredient/SmotheredChickenBreast http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/SoySauce http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/SoySauce http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/SoySauce http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Spicy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Sweet http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/TapiocaFlour http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/TapiocaFlour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Tarragon http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Tarragon http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/Tarragon http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Tart http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/ThaiChicken http://purl.org/heals/food/hasCookTime 15
# http://purl.org/heals/ingredient/ThaiChicken http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Thyme http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Thyme http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/Thyme http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Tomato http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Tomato http://purl.org/heals/food/hasGlycemicIndex 30
# http://purl.org/heals/ingredient/Tomato http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/User15 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/VanillaExtract http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/VanillaExtract http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/VanillaExtract http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/VegetableOil http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/VegetableOil http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/VegetableOil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Walnut http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Walnut http://purl.org/heals/food/hasGlycemicIndex 15
# http://purl.org/heals/ingredient/Walnut http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/Water http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/Water http://purl.org/heals/food/hasGlycemicIndex false
# http://purl.org/heals/ingredient/Water http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/WhiteBread http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/WhiteSugar http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/WhiteSugar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/WhiteVinegar http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/WhiteVinegar http://purl.org/heals/food/hasGlycemicIndex 5
# http://purl.org/heals/ingredient/WhiteVinegar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/WholeGrainBananaPancake http://purl.org/heals/food/hasCookTime 20
# http://purl.org/heals/ingredient/WholeGrainBananaPancake http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/WholeGrainMustard http://purl.org/heals/food/hasGluten 0
# http://purl.org/heals/ingredient/WholeGrainMustard http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://purl.org/heals/ingredient/WholeWheatFlour http://purl.org/heals/food/hasGluten 1
# http://purl.org/heals/ingredient/WholeWheatFlour http://purl.org/heals/food/hasGlycemicIndex 40
# http://purl.org/heals/ingredient/WholeWheatFlour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://www.omg.org/techprocess/ab/SpecificationMetadata/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf
# http://www.w3.org/2002/07/owl#NamedIndividual http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://www.w3.org/2002/07/owl#Ontology http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# http://www.w3.org/2002/07/owl#imports http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2002/07/owl#imports http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2002/07/owl#imports
# http://www.w3.org/2002/07/owl#priorVersion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2002/07/owl#priorVersion http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2002/07/owl#priorVersion
# http://www.w3.org/2002/07/owl#versionIRI http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2002/07/owl#versionIRI http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2002/07/owl#versionIRI
# http://www.w3.org/2004/02/skos/core#altLabel http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2004/02/skos/core#altLabel http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2004/02/skos/core#altLabel
# http://www.w3.org/2004/02/skos/core#changeNote http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2004/02/skos/core#changeNote http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2004/02/skos/core#changeNote
# http://www.w3.org/2004/02/skos/core#definition http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2004/02/skos/core#definition http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#editorialNote http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2004/02/skos/core#editorialNote http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2004/02/skos/core#editorialNote
# http://www.w3.org/2004/02/skos/core#scopeNote http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/2004/02/skos/core#scopeNote http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2004/02/skos/core#scopeNote
# http://www.w3.org/ns/prov#wasDerivedFrom http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/ns/prov#wasDerivedFrom http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/ns/prov#wasDerivedFrom
# https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright http://www.w3.org/2000/01/rdf-schema#subPropertyOf https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright
# http://opensource.org/licenses/MIT http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# false http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# true http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 2019-04-12 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 0 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 1 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 3 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 4 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 5 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 5 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 6 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 10 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 10 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 12 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# 15 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# ...
# https://www.foxyfolksy.com/nilagang-baka-filipino-beef-soup-vegetables/ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://www.kingarthurflour.com/recipes/basic-muffins-with-berry-and-oatmeal-versions-recipe http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://www.kingarthurflour.com/recipes/golden-kamut-bread-recipe http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://www.kingarthurflour.com/recipes/simply-perfect-pancakes-recipe http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://www.myrecipes.com/quick-and-easy/how-to-cook-pot-roast http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# https://www.recipetips.com/glossary-term/t--36245/beef-stew.asp http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# kamut http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# kamut flour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# kamut muffin http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# kamut pancake http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# khorasan wheat (kamut) is an ancient grain http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# kingarthurflour.com, "GOLDEN KAMUT BREAD. [Online]. Available: https://www.kingarthurflour.com/recipes/golden-kamut-bread-recipe. [Accessed Nov.9, 2018] http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# kingarthurflour.com, "baking with ancient grains: KAMUT FLOUR." [Online]. Available: https://www.kingarthurflour.com/guides/baking-with-ancient-grains/kamut-flour/. [Accessed Nov.9, 2018] http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# lamb http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# lemon juice http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# mayonnaise http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# milk obtained from a cow http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# minced red meat cooked in a gravy or sauce with onions and sometimes other vegetables, such as peas, celery or carrots, and topped with a layer of mashed potato before it is baked http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# minute http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# minutes http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# moist http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# mushy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# nutty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# oat http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# of, seasoned with, or containing salt http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# olive oil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# onion http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# oregano http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# paprika http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# parsley http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# peanut http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# pear-shaped fruit of a West Indian annual vine (Sechium edule) of the gourd family that is widely cultivated as a vegetable http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# pecan http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# pot roast with vegetables http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# potato http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# prepared mustard with visible mustard seeds http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# pumpkin seed http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# recipe http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# relating or conforming to a thermometric scale on which under standard atmospheric pressure the boiling point of water is at 212 degrees above the zero of the scale, the freezing point is at 32 degrees above zero, and the zero point approximates the temperature produced by mixing equal quantities by weight of snow and common salt http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# relating to, conforming to, or having the international thermometric scale on which the interval between the triple point of water and the boiling point of water is divided into 99.99 degrees with 0.01° representing the triple point and 100° the boiling point http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# represents an individual user http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# resembling cream (as in color, texture, or taste) http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# rosemary http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# salt http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# salty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# saucy shepherd pie http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# sesame oil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# slightly or moderately wet http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# slow-cooked beef with carrots, potatoes, or other vegetables added partway through cooking http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# smoky http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# smothered chicken breast http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# soft sugar whose crystals are covered by a film of refined dark syrup http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# soy sauce http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# spicy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# starch made from corn and used in foods as a thickening agent, in making corn syrup and sugars, and in the manufacture of adhesives and sizes for paper and textiles http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# sugar obtained from sugar cane, identical with that obtained from the sugar beet http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# suggestive of smoke especially in flavor or odor http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# sweet http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# syrup prepared from corn http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# tapioca flour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# tarragon http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# tart http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# thai chicken http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the aromatic flower buds of a tree in the family Myrtaceae http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the back and sides of the hog, salted and dried or smoked, usually sliced thin and fried for food http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the clear, potable liquid contained within the young hollow seed of the coconut palm http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the common domestic fowl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the curd of milk separated from the whey and prepared in many ways as a food http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the dried or fresh leaves of a basil used especially as a seasoning http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the edible seed of a pumpkin http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the edible, usually bluish berry of various shrubs belonging to the genus Vaccinium, of the heath family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the flesh of an adult domestic bovine used as food http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the furrowed nut of any of a genus (Juglans of the family Juglandaceae, the walnut family) of deciduous trees http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the large, hard-shelled seed of the coconut palm, lined with a white edible meat, and containing a milky liquid http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the liquid that descends from the clouds as rain, forms streams, lakes, and seas, and is a major constituent of all living matter and that when pure is an odorless, tasteless, very slightly compressible liquid oxide of hydrogen H2O which appears bluish in thick layers, freezes at 0° C and boils at 100° C, has a maximum density at 4° C and a high specific heat, is feebly ionized to hydrogen and hydroxyl ions, and is a poor conductor of electricity and a good solvent http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the measured or measurable period during which an action, process, or condition exists or continues http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the meat of sheep http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the mild-flavored, unripe fruit of the bell or sweet pepper, Capsicum annuum grossum, used as a greenvegetable http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the nutlike kernel of the fruit of either of two trees, Prunus dulcis (sweet almond) or P. dulcis amara (bitter almond), which grow in warm temperate regions http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the pod or the enclosed edible seed of the plant, Arachis hypogaea, of the legume family: the pod is forced underground in growing, where it ripens http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the roundish reproductive body produced by a female chicken http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the sixtieth part (1/60) of an hour; sixty seconds http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the strains of yeast commonly used as a leavening agent in baking bread and bakery products, where it converts the fermentable sugars present in the dough into carbon dioxide and ethanol http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the strong-scented leaves of the coriander plant, used in salads or to flavor and garnish food http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the user with ID 15 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# the usually large, rounded, edible, pulpy berry of an herb (genus Solanum) of the nightshade family native to South America that is typically red but may be yellow, orange, green, or purplish in color and is eaten raw or cooked as a vegetable http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# thyme http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# tomato http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# used as a flavor http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# used as a texture http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# used as an ingredient http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# user 15 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# usually freshly squeezed juice of lemons http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# value of temperature http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# value of time http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# vanilla extract http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# vegetable oil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# vocabulary.com, "chicken broth." [Online]. Available: https://www.vocabulary.com/dictionary/chicken%20broth. [Accessed Nov. 10, 2018] http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# walnut http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# water http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# white bread http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# white sugar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# white vinegar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# whole grain banana pancake http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# whole grain mustard http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# whole wheat flour http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource
# widely cultivated for its pungent compound bulbs much used in cookery http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Resource

# %% [markdown]
# **give three examples of how RDF semantics could aid the chefs in your restaurant**
#
# RDF semantics could aid the chefs as it could manage the informations easier. For instance, given the fresh ingredients that he has that day the chef could look for which recipes he could do.
# He could also easily make a menu that contains recipes for people with different allergies
# He could also build a class for each color anc then fill it with item ingredients of the same color. In this way he coul easily look for ingredients of a given color.
#
# **which properties and classes could you add to the wtm and ind vocabularies to further describe your recipe and ingredient knowledge graph, aiding the chefs in your restaurant?**
#
# Some classes could be added in order to make the access to the recipes easier an thus all the ingredients could be inserted in related subclasses. In addition to that new classes could be added, as to specify how much time does the recipe take to be prepared, or if it is a recipe specific to some particular event
